# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = "C:\\Users\\miqba\\Desktop\\DataSets\\diabetes.csv"
sep = ","

dft = AV.AutoViz(
    filename    
)
# Out:
# Shape of your Data Set loaded: (768, 9)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# <style type="text/css">
# #T_e451f_row0_col0, #T_e451f_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_e451f_row0_col1, #T_e451f_row0_col6, #T_e451f_row1_col1, #T_e451f_row1_col6, #T_e451f_row2_col1, #T_e451f_row2_col6, #T_e451f_row3_col1, #T_e451f_row3_col6, #T_e451f_row4_col1, #T_e451f_row4_col6, #T_e451f_row5_col1, #T_e451f_row5_col6, #T_e451f_row6_col1, #T_e451f_row6_col6, #T_e451f_row7_col1, #T_e451f_row7_col6, #T_e451f_row8_col1, #T_e451f_row8_col6 {
#   font-family: Segoe UI;
# }
# ...
